# %% [markdown]
# Objective:
# Summarize key insights on trader behavior across market sentiment
# regimes and derive actionable implications for trading strategy.
#
#
# 🔑 Key Insights (THIS IS THE CORE)
# 1️⃣ Profitability peaks during Greed, not Extreme Greed
#
# Average PnL is highest during Greed
# Performance drops in Extreme Greed despite higher activity
#
# Insight:
# Moderate optimism supports healthy trends; excessive euphoria hurts returns.
#
#
# 2️⃣ Higher win rate does NOT guarantee higher profit
#
# Extreme Greed has the highest win rate (~49%)
# But lower average PnL due to large loss events
#
# Insight:
# Frequent small wins are offset by occasional large losses.
#
#
# 3️⃣ Risk-taking is highest during Extreme Greed and Fear
#
# Largest average position sizes observed in:
# 1.Extreme Greed
# 2.Fear
#
# Insight:
# Emotional market conditions amplify risk-taking behavior.
#
# 4️⃣ Best risk–reward balance occurs during Greed
#
# 1.Moderate position sizes
# 2.Strong average PnL
# 3.Reasonable win rate
#
# Insight:
# Disciplined exposure during Greed outperforms aggressive trading.
#
# 5️⃣ Fear markets are not unprofitable
#
# 1.Fear still shows positive average PnL
# 2.Volatility creates opportunity for skilled traders
#
# Insight:
# Fear favors tactical, volatility-aware strategies
#
# 6️⃣ Neutral markets are the weakest environment
#
# 1.Lowest win rate
# 2.Lowest average PnL
# 3.Smallest position sizes
#
# Insight:
# Sideways markets offer limited opportunity and poor expectancy.
#
#
# Market sentiment significantly influences both trader behavior and
# performance. While Extreme Greed encourages aggressive positioning
# and frequent wins, it leads to inferior risk-adjusted returns. The
# most favorable trading environment is moderate Greed, where disciplined
# risk-taking aligns with strong market trends. These findings highlight
# the importance of sentiment-aware risk management in trading strategy
# design.
